# %% [markdown]
# # AURA ASCII JEPA World Model — Drive-Persistent
# JEPA latent-space predictor for Unicode glyph corridors. Saves to Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/SotoAlt/aura.git /content/aura 2>/dev/null || (cd /content/aura && git pull)
# !pip install -q torch torchvision numpy

# %%
# !mkdir -p /content/drive/MyDrive/aura/checkpoints
# !cd /content/aura && python -m world_model.ascii_model.jepa_model \
    --data data/ascii_training.npz \
    --epochs 50 \
    --batch-size 64 \
    --checkpoint /content/drive/MyDrive/aura/checkpoints/ascii_jepa.pt \
    --device cuda

# %%
# Show last generated frames from training output above
# To sample more, run:
# !cd /content/aura && python -m world_model.ascii_model.sample --checkpoint /content/drive/MyDrive/aura/checkpoints/ascii_jepa.pt --steps 10
